# %% [markdown]
# <a href="https://colab.research.google.com/github/mirelalisboa/S1_R3---AT1_LOPAL_T2/blob/main/S1_R3_AT1_LOPAL_T2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **exercicio 1** ❄

# %%
for numero in range(0, 101):
    if numero % 2 == 0:
        print(f"O número {numero} é PAR.")
    else:
        print(f"O número {numero} é ÍMPAR.")
# Out:
# O número 0 é PAR.
# O número 1 é ÍMPAR.
# O número 2 é PAR.
# O número 3 é ÍMPAR.
# O número 4 é PAR.
# O número 5 é ÍMPAR.
# O número 6 é PAR.
# O número 7 é ÍMPAR.
# O número 8 é PAR.
# O número 9 é ÍMPAR.
# O número 10 é PAR.
# O número 11 é ÍMPAR.
# O número 12 é PAR.
# O número 13 é ÍMPAR.
# O número 14 é PAR.
# O número 15 é ÍMPAR.
# O número 16 é PAR.
# O número 17 é ÍMPAR.
# O número 18 é PAR.
# O número 19 é ÍMPAR.
# O número 20 é PAR.
# O número 21 é ÍMPAR.
# O número 22 é PAR.
# O número 23 é ÍMPAR.
# O número 24 é PAR.
# O número 25 é ÍMPAR.
# O número 26 é PAR.
# O número 27 é ÍMPAR.
# O número 28 é PAR.
# O número 29 é ÍMPAR.
# O número 30 é PAR.
# O número 31 é ÍMPAR.
# O número 32 é PAR.
# O número 33 é ÍMPAR.
# O número 34 é PAR.
# O número 35 é ÍMPAR.
# O número 36 é PAR.
# O número 37 é ÍMPAR.
# O número 38 é PAR.
# O número 39 é ÍMPAR.
# O número 40 é PAR.
# O número 41 é ÍMPAR.
# O número 42 é PAR.
# O número 43 é ÍMPAR.
# O número 44 é PAR.
# O número 45 é ÍMPAR.
# O número 46 é PAR.
# O número 47 é ÍMPAR.
# O número 48 é PAR.
# O número 49 é ÍMPAR.
# O número 50 é PAR.
# O número 51 é ÍMPAR.
# O número 52 é PAR.
# O número 53 é ÍMPAR.
# O número 54 é PAR.
# O número 55 é ÍMPAR.
# O número 56 é PAR.
# O número 57 é ÍMPAR.
# O número 58 é PAR.
# O número 59 é ÍMPAR.
# O número 60 é PAR.
# O número 61 é ÍMPAR.
# O número 62 é PAR.
# O número 63 é ÍMPAR.
# O número 64 é PAR.
# O número 65 é ÍMPAR.
# O número 66 é PAR.
# O número 67 é ÍMPAR.
# O número 68 é PAR.
# O número 69 é ÍMPAR.
# O número 70 é PAR.
# O número 71 é ÍMPAR.
# O número 72 é PAR.
# O número 73 é ÍMPAR.
# O número 74 é PAR.
# O número 75 é ÍMPAR.
# O número 76 é PAR.
# O número 77 é ÍMPAR.
# O número 78 é PAR.
# O número 79 é ÍMPAR.
# O número 80 é PAR.
# O número 81 é ÍMPAR.
# O número 82 é PAR.
# O número 83 é ÍMPAR.
# O número 84 é PAR.
# O número 85 é ÍMPAR.
# O número 86 é PAR.
# O número 87 é ÍMPAR.
# O número 88 é PAR.
# O número 89 é ÍMPAR.
# O número 90 é PAR.
# O número 91 é ÍMPAR.
# O número 92 é PAR.
# O número 93 é ÍMPAR.
# O número 94 é PAR.
# O número 95 é ÍMPAR.
# O número 96 é PAR.
# O número 97 é ÍMPAR.
# O número 98 é PAR.
# O número 99 é ÍMPAR.
# O número 100 é PAR.

# %% [markdown]
# **exercicio 2** ⚛

# %%
numeros = [15, 8, 42]

maior_numero = max(numeros)
menor_numero = min(numeros)

print(f"A lista é: {numeros}")
print(f"O maior número é: {maior_numero}")
print(f"O menor número é: {menor_numero}")
# Out:
# A lista é: [15, 8, 42]
# O maior número é: 42
# O menor número é: 8

# %% [markdown]
# **exercicio 3** ♦

# %%
nome = input("Digite o nome: ")

for i in range(len(nome)):
    print(nome[:i+1])
# Out:
# Digite o nome: carlos morato
# c
# ca
# car
# carl
# carlo
# carlos
# carlos
# carlos m
# carlos mo
# carlos mor
# carlos mora
# carlos morat
# carlos morato
# carlos morato

# %% [markdown]
# **exercicio 5** ♾

# %%
nome = input("Por favor, digite o seu nome: ")
while len(nome) <= 3:
  nome = input("Número de caracteres insuficientes, digite novamente:")

idade = int(input("Agora digite a sua idade, por gentileza: "))
while idade < 0 or idade > 150:
  idade = int(input("Idade inválida, digite novamente:"))

salario = float(input("Digite o seu salário: "))
while salario <= 0:
  salario = float(input("Salário inválido, digite novamente:"))

sexo = input("Por favor, digite o seu sexo (f/m): ")
while sexo != "f" and sexo != "m":
  sexo = input("Sexo não identificado, digite novamente: ")

estado = input("Por fim, digite o seu estado civil (s/c/v/d), por favor: ")
while estado != "s" and estado != "c" and estado != "v" and estado != "d":
  estado = input("Estado civil não identificado, digite novamente: ")

print("Dados válidos, agradecemos a sua colaboração!")
# Out:
# Por favor, digite o seu nome: mirela
# Agora digite a sua idade, por gentileza: 16
# Digite o seu salário: 4000
# Por favor, digite o seu sexo (f/m): f
# Por fim, digite o seu estado civil (s/c/v/d), por favor: s
# Dados válidos, agradecemos a sua colaboração!

# %% [markdown]
# **exercicio 6** ♟

# %%
numero = int(input("Digite um número inteiro: "))

if numero <= 1:
    print(f"O número {numero} NÃO é primo.")
elif numero == 2:
    print(f"O número {numero} É primo.")
else:
    i_primo = True
    for i in range(2, numero):
        if numero % i == 0:
            i_primo = False
            break
    if i_primo:
        print(f"O número {numero} É primo.")
    else:
        print(f"O número {numero} NÃO é primo.")
# Out:
# Digite um número inteiro: 7
# O número 7 É primo.

# %% [markdown]
# **exercicio 7** ✡

# %%
n = int(input("Fatorial de: "))
f = 1

for i in range(1, n + 1):
    f *= i

print(f)
# Out:
# Fatorial de: 80
# 71569457046263802294811533723186532165584657342365752577109445058227039255480148842668944867280814080000000000000000000

# %% [markdown]
# **exercicio 8** ☢

# %%
L = [5, 7, 2, 9, 4, 1, 3]
print(f"O tamanho da lista é:", len(L))
print(f"O maior valor da lista é:", max(L))
print(f"O menor valor da lista é:", min(L))
print(f"A soma dos elementos da lista é:", sum(L))
L.sort()
print("A ordem crescente é:", L)
L.sort(reverse=True)
print("A ordem decrescente é:", L)
# Out:
# O tamanho da lista é: 7
# O maior valor da lista é: 9
# O menor valor da lista é: 1
# A soma dos elementos da lista é: 31
# A ordem crescente é: [1, 2, 3, 4, 5, 7, 9]
# A ordem decrescente é: [9, 7, 5, 4, 3, 2, 1]

# %% [markdown]
# **exercicio 9** ✴

# %%
lanchonete = {
    "Salgado": 4.50,
    "Lanche": 6.50,
    "Suco": 3.00,
    "Refrigerante": 3.50,
    "Doce": 1.00
}
print(lanchonete)
# Out:
# {'Salgado': 4.5, 'Lanche': 6.5, 'Suco': 3.0, 'Refrigerante': 3.5, 'Doce': 1.0}

# %% [markdown]
# **exercicio 10** ☣

# %%
senha = input("Digite a senha: ")
while senha != "676767":
  senha = input("Acesso negado, tente mais uma vez: ")
print("Acesso ok, pode usar!")
# Out:
# Digite a senha: 656869
# Acesso negado, tente mais uma vez: 676767
# Acesso ok, pode usar!

# %% [markdown]
# **exercicio 11** ⏭

# %%
num = int(input("Tabuada do: "))

for i in range(1, 11):
    print(num, "x", i, "=", num * i)
# Out:
# Tabuada do: 1
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
